# %% [markdown]
# ## Import the libararies and the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %% [markdown]
# ## Visualise the Dataset

# %%
non_fraud = df[df['Class']==0]
fraud = df[df['Class']==1]

# %%
print('No. of fraudulent transactions = ',len(fraud)/len(df)*100)
print('No. of non fraudulent transactions = ',len(non_fraud)/len(df)*100)
# Out:
# No. of fraudulent transactions =  0.1727485630620034
# No. of non fraudulent transactions =  99.82725143693798

# %%
sns.countplot(df['Class'])

# %%
plt.figure(figsize=(30,10))
sns.heatmap(df.corr(),annot=True)

# %%
column_headers = df.columns.values

# %%
i = 1

fig,axes = plt.subplots(8,4,figsize=(18,30))
for column_header in column_headers:
    plt.subplot(8,4,i)
    sns.kdeplot(fraud[column_header],bw=0.4,shade=True,color='r',label='Fraud',linestyle="--")
    sns.kdeplot(non_fraud[column_header],bw=0.4,shade=True,color='g',label='Fraud',linestyle=":")
    plt.title(column_header, fontsize=12)
    i = i + 1
plt.show();

# %% [markdown]
# ## Creating the Training and Testing Data

# %%
# Normalising the Amount column
from sklearn.preprocessing import StandardScaler
standardscaler = StandardScaler()
df['AmountNormalised'] = standardscaler.fit_transform(df['Amount'].values.reshape(-1,1))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
df.drop('Amount',axis = 1,inplace = True)

# %%
X = df.drop(['Class'],axis = 1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split as tts
X_train,X_test,y_train,y_test = tts(X,y,test_size = 0.2)

# %% [markdown]
# ## Training the Model

# %%
X_train.shape
# Out:
# (227845, 30)

# %%
y_train.shape
# Out:
# (227845,)

# %%
X_test.shape
# Out:
# (56962, 30)

# %%
y_test.shape
# Out:
# (56962,)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ## Evaluate the Model

# %%
from sklearn.metrics import classification_report,confusion_matrix
y_pred_train = classifier.predict(X_train)
y_pred_test = classifier.predict(X_test)
cm_train = confusion_matrix(y_train,y_pred_train)
cm_test = confusion_matrix(y_test,y_pred_test)

# %%
# Training results

# %%
sns.heatmap(cm_train,annot=True)

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    227446
#            1       0.14      0.63      0.23       399
#
#    micro avg       0.99      0.99      0.99    227845
#    macro avg       0.57      0.81      0.62    227845
# weighted avg       1.00      0.99      1.00    227845

# %%
# Test results

# %%
sns.heatmap(cm_test,annot=True)

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56869
#            1       0.15      0.71      0.25        93
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.58      0.85      0.62     56962
# weighted avg       1.00      0.99      1.00     56962

# %% [markdown]
# ## Improving the Model

# %%
# Drop the similar features column

# %%
X = df.drop(['Time','V8','V13','V15','V20','V22','V23','V24','V25','V26','V27','V28','Class'], axis = 1)

# %%
X_train,X_test,y_train,y_test = tts(X,y,test_size=0.2)
classifier_new = GaussianNB()
classifier_new.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_testing = classifier_new.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred_testing)
sns.heatmap(cm,annot=True)

# %%
print(classification_report(y_test,y_pred_testing))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56841
#            1       0.11      0.84      0.19       121
#
#    micro avg       0.98      0.98      0.98     56962
#    macro avg       0.55      0.91      0.59     56962
# weighted avg       1.00      0.98      0.99     56962
